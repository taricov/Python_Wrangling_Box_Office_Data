# %%
import pandas as pd

# %%
box_office = pd.read_csv("box_office.csv", encoding='latin-1')
box_office
# Out:
#                      title country  year_release  box_office type_of_subject  \
# 0      10 Rillington Place      UK          1971         NaN        Criminal
# 1         12 Years a Slave   US/UK          2013  56700000.0           Other
# 2                127 Hours   US/UK          2010  18300000.0         Athlete
# 3                     1987  Canada          2014         NaN           Other
# 4                 20 Dates      US          1998    537000.0           Other
# ..                     ...     ...           ...         ...             ...
# 758  Young Man with a Horn      US          1950         NaN        Musician
# 759      Young Mr. Lincoln      US          1939         NaN    World leader
# 760       Young Tom Edison      US          1940         NaN           Other
# 761          Young Winston      US          1972         NaN    World leader
# 762    Your Cheatin' Heart      US          1964         NaN        Musician
#
#        lead_actor_actress
# 0    Richard Attenborough
# 1        Chiwetel Ejiofor
# 2            James Franco
# 3       Jean-Carl Boucher
# 4         Myles Berkowitz
# ..                    ...
# 758          Kirk Douglas
# 759           Henry Fonda
# 760         Mickey Rooney
# 761            Simon Ward
# 762       George Hamilton
#
# [763 rows x 6 columns]

# %%
def wrangler(box_office):
    #drop duplicates:
    box_office = box_office.drop_duplicates()
    #rename box_office col:
    box_office = box_office.rename(columns={'box_office':'earnings'})
    #filter out the NA values:
    box_office = box_office[~ box_office['earnings'].isna()]
    #filter by year:
    box_office = box_office[box_office['year_release'] >= 1990]
    #change data type:
    box_office[['country', 'type_of_subject']] = box_office[['country', 'type_of_subject']].astype('category')
    #creating new col:
    box_office.loc[box_office['lead_actor_actress'] == box_office['lead_actor_actress'].isna(), 'lead_actor_actress_known'] = 'Flase'  
    box_office.loc[box_office['lead_actor_actress'] != box_office['lead_actor_actress'].isna(), 'lead_actor_actress_known'] = 'True'  
    #earnings processing:
    box_office['earnings'] = box_office['earnings']/1000
    #select important cols:
    box_office = box_office[['title', 'year_release', 'earnings', 'country', 'type_of_subject', 'lead_actor_actress', 'lead_actor_actress_known']]
    #sorting:
    box_office = box_office.sort_values(by='earnings', ascending=False)
    # displaying final results:
    display(box_office)

wrangler(box_office)
# Out:
#                      title  year_release   earnings    country  \
# 38         American Sniper          2014  350000.00         US
# 547         The Blind Side          2009  256000.00         US
# 334                Lincoln          2012  182000.00         US
# 11        A Beautiful Mind          2001  171000.00         US
# 124    Catch Me If You Can          2002  164000.00  US/Canada
# ..                     ...           ...        ...        ...
# 409                   Nora          2000      12.30         UK
# 624       The Look of Love          2013      10.40      US/UK
# 183                Ed Gein          2000       5.71      US/UK
# 314           Kid Cannabis          2014       5.57         US
# 485  Set Fire to the Stars          2014       3.27         UK
#
#     type_of_subject     lead_actor_actress lead_actor_actress_known
# 38         Military         Bradley Cooper                     True
# 547         Athlete          Quinton Aaron                     True
# 334    World leader       Daniel Day-Lewis                     True
# 11         Academic          Russell Crowe                     True
# 124        Criminal      Leonardo DiCaprio                     True
# ..              ...                    ...                      ...
# 409           Other            Susan Lynch                     True
# 624           Other           Steve Coogan                     True
# 183        Criminal        Steve Railsback                     True
# 314        Criminal  Jonathan Daniel Brown                     True
# 485   Author (poet)            Celyn Jones                     True
#
# [360 rows x 7 columns]
